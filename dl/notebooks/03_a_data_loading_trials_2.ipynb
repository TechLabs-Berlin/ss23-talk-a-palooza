# %%
from google.colab import drive

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import re

# %% [markdown]
# https://colab.research.google.com/github/fastaudio/fastaudio/blob/master/docs/ESC50:%20Environmental%20Sound%20Classification.ipynb#scrollTo=bp4PfvDBAQWu

# %%
# !pip install fastaudio

# %% [markdown]
# Restart runtime!

# %%
from fastai.vision.all import *
from fastaudio.core.all import *
from fastaudio.augment.all import *
from fastaudio.ci import skip_if_ci

# %% [markdown]
# Due to receiving an `No module named 'torchvision.models.utils'` ModuleNotFoundError from torchvision, I opened and modified xresnet.py
# `/usr/local/lib/python3.10/dist-packages/fastai/vision/models/xresnet.py in <module>`:
#
# Change line 13 from `from torchvision.models.utils import load_state_dict_from_url` to `from torch.hub import load_state_dict_from_url`

# %%
#The first time this will download a dataset that is ~650mb
# path = untar_data(URLs.ESC50, dest="ESC50")

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
src = '/content/drive/MyDrive/talkapalooza/labelled_audio'

# %%
audio_data = get_files(src, extensions=audio_extensions)

# %%
Path(src).ls()
# Out:
# (#471) [Path('/content/drive/MyDrive/talkapalooza/labelled_audio/yellow'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/big'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/nose'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/where'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/hear'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/hair'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/vacuum'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/bedroom'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/picture'),Path('/content/drive/MyDrive/talkapalooza/labelled_audio/above')...]

# %% [markdown]
# Recreate a dataframe of similar format:

# %%
path = untar_data(URLs.ESC50, dest="ESC50")
df = pd.read_csv(path/"meta"/"esc50.csv")
df.head()
# Out:
#             filename  fold  target        category  esc10  src_file take
# 0   1-100032-A-0.wav     1       0             dog   True    100032    A
# 1  1-100038-A-14.wav     1      14  chirping_birds  False    100038    A
# 2  1-100210-A-36.wav     1      36  vacuum_cleaner  False    100210    A
# 3  1-100210-B-36.wav     1      36  vacuum_cleaner  False    100210    B
# 4  1-101296-A-19.wav     1      19    thunderstorm  False    101296    A

# %%
audio_df = pd.DataFrame(columns=['filepath', 'fold', 'label', 'author'])

# %%
for f in audio_data:
  f_label = f.name.split('--')[0]
  f_author = f.name.split('--')[1][:-4]
  fpath = f"/{f_label}/{f.name}"
  temp_df = pd.DataFrame([[fpath, np.nan, f_label, f_author]], columns=['filepath', 'fold', 'label', 'author'])
  audio_df = pd.concat([audio_df, temp_df])

# %%
audio_df.head()
# Out:
#                              filepath fold   label          author
# 0       /yellow/yellow--Back-ache.ogg  NaN  yellow       Back-ache
# 0  /yellow/yellow--Nattes-à-chat.ogg  NaN  yellow  Nattes-à-chat
# 0        /yellow/yellow--Lirazelf.ogg  NaN  yellow        Lirazelf
# 0               /big/big--Opsylac.ogg  NaN     big         Opsylac
# 0              /big/big--Lirazelf.ogg  NaN     big        Lirazelf

# %% [markdown]
# ## Create Train and Test sets:

# %%
from sklearn.model_selection import KFold

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=1)

# %%
np_array = audio_df.to_numpy()

# %%
def generate_model_df (df_array):
  dfs = list()
  model = 1

  for train, test in kfold.split(df_array):
    temp_df = audio_df.copy().reset_index().drop(labels='index', axis=1).reset_index()
    temp_df['fold'] = model
    temp_df['test'] = 0

    # test_filt = (temp_df['index'].isin(test))
    # temp_df.loc[test_filt]['test'] = 1

    for i in test:
      temp_df.loc[i, 'test'] = 1

    temp_df.drop(labels='index', axis=1, inplace=True)

    dfs.append(temp_df)
    model = model+1

  return dfs

# %%
dfs = generate_model_df(np_array)

# %%
dfs[0].head(10)
# Out:
#                              filepath  fold   label          author  test
# 0       /yellow/yellow--Back-ache.ogg     1  yellow       Back-ache     0
# 1  /yellow/yellow--Nattes-à-chat.ogg     1  yellow  Nattes-à-chat     0
# 2        /yellow/yellow--Lirazelf.ogg     1  yellow        Lirazelf     0
# 3               /big/big--Opsylac.ogg     1     big         Opsylac     0
# 4              /big/big--Lirazelf.ogg     1     big        Lirazelf     0
# 5             /big/big--Back-ache.ogg     1     big       Back-ache     0
# 6              /big/big--Greenman.ogg     1     big        Greenman     1
# 7           /big/big--SpringProof.ogg     1     big     SpringProof     0
# 8        /big/big--Vivekteraiyavt.ogg     1     big  Vivekteraiyavt     0
# 9          /big/big--She-animates.ogg     1     big    She-animates     0

# %% [markdown]
# ## Datablock and Dataloader preparation:

# %% [markdown]
# Do I need this function, seeing as the different folds are already split into separate dataframes?

# %%
# Helper function to split the data
def CrossValidationSplitter(col='fold', fold=1):
    "Split `items` (supposed to be a dataframe) by fold in `col`"
    def _inner(o):
        assert isinstance(o, pd.DataFrame), "ColSplitter only works when your items are a pandas DataFrame"
        col_values = o.iloc[:,col] if isinstance(col, int) else o[col]
        valid_idx = (col_values == fold).values.astype('bool')
        return IndexSplitter(mask2idxs(valid_idx))(o)
    return _inner

# %%
# cfg = AudioConfig.Voice()
cfg = AudioConfig.BasicMelSpectrogram(n_fft=512)
a2s = AudioToSpec.from_cfg(cfg)

# %%
auds = DataBlock(blocks = (AudioBlock, CategoryBlock),
                 get_x = ColReader("filepath", pref=src),
                 # splitter = CrossValidationSplitter(fold=1),
                 batch_tfms = [a2s],
                 get_y = ColReader("label"))

# %%
dbunch = auds.dataloaders(dfs[0], bs=64)
# Out:
# /usr/local/lib/python3.10/dist-packages/fastaudio/augment/preprocess.py:86: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   sig_np = ai.numpy()
# /usr/local/lib/python3.10/dist-packages/fastaudio/augment/preprocess.py:91: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   ai.data = torch.from_numpy(resampled.astype(np.float32))
# /usr/local/lib/python3.10/dist-packages/fastaudio/augment/signal.py:202: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   downmixed = ai.data.contiguous().mean(-2).unsqueeze(-2)
# /usr/local/lib/python3.10/dist-packages/fastai/torch_core.py:132: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   if res.dtype is torch.float64: return res.float()
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/collate.py:162: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   return torch.stack(batch, 0, out=out)
# /usr/local/lib/python3.10/dist-packages/fastai/torch_core.py:250: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   def _inner(o): return o.to(device, non_blocking=True) if isinstance(o,Tensor) else o.to_device(device) if hasattr(o, "to_device") else o
# /usr/local/lib/python3.10/dist-packages/fastaudio/core/spectrogram.py:145: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   self.pipe.to(audio.device)
# /usr/local/lib/python3.10/dist-packages/fastaudio/core/signal.py:77: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   return self.shape[-2]
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:122: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   shape = waveform.size()
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:123: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   waveform = waveform.reshape(-1, shape[-1])
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:140: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   spec_f = spec_f.reshape(shape[:-1] + spec_f.shape[-2:])
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:147: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   return spec_f.abs().pow(power)
# /usr/local/lib/python3.10/dist-packages/torchaudio/transforms/_transforms.py:412: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   mel_specgram = torch.matmul(specgram.transpose(-1, -2), self.fb).transpose(-1, -2)
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:385: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   x_db = multiplier * torch.log10(torch.clamp(x, min=amin))
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:386: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:363.)
#   x_db -= multiplier * db_multiplier

# %%
dbunch.show_batch(figsize=(10, 5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-09b3a84243c5> in <cell line: 1>()
# ----> 1 dbunch.show_batch(figsize=(10, 5))
#
# /usr/local/lib/python3.10/dist-packages/fastai/data/core.py in show_batch(self, b, max_n, ctxs, show, unique, **kwargs)
#      98             old_get_idxs = self.get_idxs
#      99             self.get_idxs = lambda: Inf.zeros
# --> 100         if b is None: b = self.one_batch()
#     101         if not show: return self._pre_show_batch(b, max_n=max_n)
#     102         show_batch(*self._pre_show_batch(b, max_n=max_n), ctxs=ctxs, max_n=max_n, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/fastai/data/load.py in one_batch(self)
#     135     def one_batch(self):
#     136         if self.n is not None and len(self)==0: raise ValueError(f'This DataLoader does not contain any batches')
# --> 137         with self.fake_l.no_multiproc(): res = first(self)
#     138         if hasattr(self, 'it'): delattr(self, 'it')
#     139         return res
#
# /usr/local/lib/python3.10/dist-packages/fastcore/basics.py in first(x, f, negate, **kwargs)
#     525     x = iter(x)
#     526     if f: x = filter_ex(x, f=f, negate=negate, gen=True, **kwargs)
# --> 527     return next(x, None)
#     528
#     529 # Cell
#
# /usr/local/lib/python3.10/dist-packages/fastai/data/load.py in __iter__(self)
#      99         self.before_iter()
#     100         self.__idxs=self.get_idxs() # called in context of main process (not workers/subprocesses)
# --> 101         for b in _loaders[self.fake_l.num_workers==0](self.fake_l):
#     102             if self.device is not None: b = to_device(b, self.device)
#     103             yield self.after_batch(b)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     660 class _SingleProcessDataLoaderIter(_BaseDataLoaderIter):
#     661     def __init__(self, loader):
# --> 662         super().__init__(loader)
#     663         assert self._timeout == 0
#     664         assert self._num_workers == 0
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     588         # default behaviour is CUDA device. if pin_memory_device is selected
#     589         # and pin_memory is not set, the default behaviour false.
# --> 590         if (len(loader.pin_memory_device) == 0):
#     591             self._pin_memory = loader.pin_memory and torch.cuda.is_available()
#     592             self._pin_memory_device = None
#
# AttributeError: '_FakeLoader' object has no attribute 'pin_memory_device'
